# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()

# %% [raw]
# SPLIT THE DATA INTO TWO, FIRST HALF WILL BE USED TO TRAIN THE DATA AND THE SECOND HALF TO TEST IT.

# %%
from sklearn.model_selection import train_test_split

X = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6842     -118.13     34.06                17.0       1714.0           572.0
# 2686     -115.53     32.97                35.0       1583.0           340.0
# 16426    -121.42     38.22                35.0       1507.0           313.0
# 10554    -117.71     33.63                16.0       1565.0           274.0
# 17106    -122.20     37.46                40.0       1723.0           208.0
# ...          ...       ...                 ...          ...             ...
# 20002    -119.21     36.10                30.0       1471.0           373.0
# 14628    -117.18     32.76                17.0        711.0           254.0
# 17890    -121.94     37.42                16.0       3936.0           788.0
# 7295     -118.21     33.97                35.0       1863.0           537.0
# 9392     -122.54     37.91                48.0       2924.0           489.0
#
# ...

# %%
brev = train_data.drop(['ocean_proximity'], axis=1)

# %%
train_data.hist()
# Out:
# array([[<AxesSubplot: title={'center': 'longitude'}>,
#         <AxesSubplot: title={'center': 'latitude'}>,
#         <AxesSubplot: title={'center': 'housing_median_age'}>],
#        [<AxesSubplot: title={'center': 'total_rooms'}>,
#         <AxesSubplot: title={'center': 'total_bedrooms'}>,
#         <AxesSubplot: title={'center': 'population'}>],
#        [<AxesSubplot: title={'center': 'households'}>,
#         <AxesSubplot: title={'center': 'median_income'}>,
#         <AxesSubplot: title={'center': 'median_house_value'}>]],
#       dtype=object)

# %%
brev.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924721           -0.108960     0.045868
# latitude            -0.924721  1.000000            0.010959    -0.039313
# housing_median_age  -0.108960  0.010959            1.000000    -0.364296
# total_rooms          0.045868 -0.039313           -0.364296     1.000000
# total_bedrooms       0.070496 -0.070155           -0.321293     0.928865
# population           0.100561 -0.112612           -0.299794     0.860389
# households           0.057160 -0.074873           -0.304024     0.917784
# median_income       -0.014639 -0.081052           -0.117368     0.203585
# median_house_value  -0.042461 -0.146757            0.105256     0.141046
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.070496    0.100561    0.057160      -0.014639
# latitude                 -0.070155   -0.112612   -0.074873      -0.081052
# ...

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(brev.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot: >

# %%
brev['total_rooms'] = np.log(train_data['total_rooms'] + 1)
brev['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
brev['population'] = np.log(train_data['population'] + 1)
brev['households'] = np.log(train_data['households'] + 1)
